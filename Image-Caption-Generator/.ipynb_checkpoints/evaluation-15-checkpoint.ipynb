# %%
import json
from tensorflow.keras.models import load_model
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.sequence import pad_sequences
import collections
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.resnet50 import  preprocess_input, decode_predictions
from tensorflow.keras.models import Model

# %%
# Read the files word_to_idx.pkl and idx_to_word.pkl to get the mappings between word and index
word_to_index = {}
with open ("data/textFiles/word_to_idx.pkl", 'rb') as file:
    word_to_index = pd.read_pickle(file, compression=None)

index_to_word = {}
with open ("data/textFiles/idx_to_word.pkl", 'rb') as file:
    index_to_word = pd.read_pickle(file, compression=None)



print("Loading the model...")
model = load_model('model_checkpoints/model_15.h5')

modelvgg = VGG16(include_top=True,weights=None)
modelvgg.load_weights('/data/disk2/stu_yue/vgg16_weights_tf_dim_ordering_tf_kernels.h5')
modelvgg.layers.pop()
model_new = Model(inputs=modelvgg.inputs, outputs=modelvgg.layers[-2].output)
# Out:
# Loading the model...

# %%
# Generate Captions for a random image
# Using Greedy Search Algorithm

def predict_caption(photo):

    inp_text = "startseq"

    #max_len = 80 which is maximum length of caption
    for i in range(80):
        sequence = [word_to_index[w] for w in inp_text.split() if w in word_to_index]
        sequence = pad_sequences([sequence], maxlen=80, padding='post')

        ypred = model.predict([photo, sequence])
        ypred = ypred.argmax()
        word = index_to_word[ypred]

        inp_text += (' ' + word)

        if word == 'endseq':
            break

    final_caption = inp_text.split()[1:-1]
    final_caption = ' '.join(final_caption)
    return final_caption

# %%
def preprocess_image (img):
    img = image.load_img(img, target_size=(224, 224))
    img = image.img_to_array(img)

    # Convert 3D tensor to a 4D tendor
    img = np.expand_dims(img, axis=0)

    #Normalize image accoring to ResNet50 requirement
    img = preprocess_input(img)

    return img

# %%
# A wrapper function, which inputs an image and returns its encoding (feature vector)
def encode_image (img):
    img = preprocess_image(img)

    feature_vector = model_new.predict(img)
    # feature_vector = feature_vector.reshape((-1,))
    return feature_vector

# %%
def runModel(img_name):
    #img_name = input("enter the image name to generate:\t")

#    print("Encoding the image ...")
    photo = encode_image(img_name).reshape((1, 4096))



#    print("Running model to generate the caption...")
    caption = predict_caption(photo)

#    img_data = plt.imread(img_name)
#    plt.imshow(img_data)
#    plt.axis("off")

    #plt.show()
#    print(caption)
    return caption

# %%
def readFile (path):
    with open(path, encoding="utf8") as file:
        data = file.read()
    return data;

# %%
data = readFile ("data/textFiles/30k_captions.txt")

# Split the data into each line, to get a list of captions
captions = data.split('\n')
# Remove the last line since it is blank
captions = captions[:-1]

# %%
content = {}
references={}
for line in captions:
    imageID, caption = line.split('\t')

    imageID = imageID.split('.')[0]

    # If the imageID doesn't exist in the dictionary, create a blank entry
    if content.get(imageID) is None:
        content[imageID] = []
        references[imageID] = []

    # Append the current caption to the list of the corresponding image
    content[imageID].append(caption)
    references[imageID].append(caption.split())

# %%
data_val = readFile ("data/textFiles/flickr30k_val.txt")
imageID_val=[]
imageID_val = data_val.split('.jpg\n')
imageID_val=imageID_val[:-1]

# %%
from nltk.translate.bleu_score import corpus_bleu
from time import time


generated_captions=['a man in a blue shirt is sitting on a lawn bench in a field'.split()]
scores=[]
good=[]
bad=[]
start_time = time()

for imageID in imageID_val:
    generated_captions=runModel('/data/disk2/stu_yue/flickr/flickr30k-images/flickr30k-images/'+imageID+'.jpg')
    generated_captions=[generated_captions.split()]
    #print('BLEU-1 Score on test data: {:.3f}'.format(corpus_bleu([references[imageID]], generated_captions, weights=(1,0,0,0)) * 100))
    score=corpus_bleu([references[imageID]], generated_captions, weights=(1,0,0,0)) * 100
    print('BLEU-1 Score on test data '+imageID+': {:.3f}'.format(score))
    scores.append(score)
    if (score>50):
        good.append(imageID)
    if (score<30):
        bad.append(imageID)
end_time = time()
print("Total time taken:", end_time-start_time, "sec")
# Out:
# /data/disk2/stu_yue/anaconda3/envs/tfgpu/lib/python3.6/site-packages/nltk/translate/bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /data/disk2/stu_yue/anaconda3/envs/tfgpu/lib/python3.6/site-packages/nltk/translate/bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# BLEU-1 Score on test data 1018148011: 28.571
# BLEU-1 Score on test data 1029450589: 50.000
# BLEU-1 Score on test data 1029737941: 35.714
# BLEU-1 Score on test data 103205630: 35.714
# BLEU-1 Score on test data 10350842: 65.000
# BLEU-1 Score on test data 1054620089: 49.766
# /data/disk2/stu_yue/anaconda3/envs/tfgpu/lib/python3.6/site-packages/nltk/translate/bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# BLEU-1 Score on test data 1056873310: 42.857
# BLEU-1 Score on test data 1072439304: 50.000
# BLEU-1 Score on test data 1073444492: 40.000
# BLEU-1 Score on test data 1092437557: 35.714
# BLEU-1 Score on test data 109671650: 42.857
# BLEU-1 Score on test data 109738763: 21.429
# BLEU-1 Score on test data 109982467: 25.000
# BLEU-1 Score on test data 110269384: 28.571
# BLEU-1 Score on test data 1107507919: 50.000
# BLEU-1 Score on test data 112243673: 21.429
# BLEU-1 Score on test data 1124448967: 45.000
# BLEU-1 Score on test data 1126137905: 20.000
# BLEU-1 Score on test data 1128874064: 38.889
# BLEU-1 Score on test data 1130017585: 30.000
# BLEU-1 Score on test data 1141643526: 55.000
# BLEU-1 Score on test data 1141718391: 35.714
# BLEU-1 Score on test data 1150429218: 35.714
# BLEU-1 Score on test data 1155138244: 27.778
# BLEU-1 Score on test data 116569042: 40.000
# BLEU-1 Score on test data 1206506157: 38.462
# BLEU-1 Score on test data 120764850: 27.778
# BLEU-1 Score on test data 121556607: 25.000
# BLEU-1 Score on test data 1215804065: 33.252
# BLEU-1 Score on test data 123244147: 28.571
# BLEU-1 Score on test data 1235099089: 42.857
# BLEU-1 Score on test data 123866385: 28.571
# BLEU-1 Score on test data 126042604: 25.000
# BLEU-1 Score on test data 1277949368: 60.000
# BLEU-1 Score on test data 128452798: 40.000
# BLEU-1 Score on test data 1296770308: 28.826
# BLEU-1 Score on test data 1306755031: 35.714
# BLEU-1 Score on test data 1335877186: 38.732
# BLEU-1 Score on test data 1341787777: 20.000
# BLEU-1 Score on test data 1343426964: 45.000
# BLEU-1 Score on test data 134642833: 57.143
# BLEU-1 Score on test data 1348517311: 35.000
# BLEU-1 Score on test data 134857559: 35.714
# BLEU-1 Score on test data 1348947380: 21.429
# BLEU-1 Score on test data 1355945307: 50.000
# BLEU-1 Score on test data 135608578: 21.429
# BLEU-1 Score on test data 1358398144: 30.000
# BLEU-1 Score on test data 135980645: 33.333
# BLEU-1 Score on test data 1361790462: 61.905
# BLEU-1 Score on test data 1363843090: 35.714
# BLEU-1 Score on test data 1368338041: 15.000
# BLEU-1 Score on test data 136886677: 35.000
# BLEU-1 Score on test data 1389264266: 50.000
# BLEU-1 Score on test data 1393205795: 31.579
# BLEU-1 Score on test data 1394319096: 26.602
# BLEU-1 Score on test data 1405665934: 63.158
# BLEU-1 Score on test data 1409723496: 38.889
# BLEU-1 Score on test data 1410039760: 45.000
# BLEU-1 Score on test data 141126420: 35.714
# BLEU-1 Score on test data 141186473: 55.000
# BLEU-1 Score on test data 1432734769: 20.000
# BLEU-1 Score on test data 1436832881: 15.789
# BLEU-1 Score on test data 143688283: 57.143
# BLEU-1 Score on test data 143793054: 42.857
# BLEU-1 Score on test data 1438769690: 45.000
# BLEU-1 Score on test data 144328407: 42.805
# BLEU-1 Score on test data 1463864223: 38.049
# BLEU-1 Score on test data 146758244: 25.000
# BLEU-1 Score on test data 14868339: 20.000
# BLEU-1 Score on test data 149042906: 50.000
# BLEU-1 Score on test data 149231190: 25.000
# BLEU-1 Score on test data 1496289999: 35.714
# BLEU-1 Score on test data 1499495021: 61.905
# BLEU-1 Score on test data 1507563902: 42.857
# BLEU-1 Score on test data 155014252: 14.286
# BLEU-1 Score on test data 1554086730: 50.000
# BLEU-1 Score on test data 156249400: 35.714
# BLEU-1 Score on test data 1567005236: 36.842
# BLEU-1 Score on test data 1581304802: 33.293
# BLEU-1 Score on test data 1588931550: 35.714
# BLEU-1 Score on test data 162839055: 35.000
# BLEU-1 Score on test data 166774567: 50.000
# BLEU-1 Score on test data 167001809: 21.053
# BLEU-1 Score on test data 1680409989: 50.000
# BLEU-1 Score on test data 1680674943: 36.787
# BLEU-1 Score on test data 1717077532: 45.000
# BLEU-1 Score on test data 172892648: 28.571
# BLEU-1 Score on test data 1732567333: 35.000
# BLEU-1 Score on test data 1745110280: 35.714
# BLEU-1 Score on test data 1752454466: 35.714
# BLEU-1 Score on test data 175369436: 50.000
# BLEU-1 Score on test data 1791491934: 45.000
# BLEU-1 Score on test data 180217379: 50.000
# BLEU-1 Score on test data 1814391289: 20.000
# BLEU-1 Score on test data 1836335410: 45.000
# BLEU-1 Score on test data 1837976956: 45.000
# BLEU-1 Score on test data 1877161207: 21.429
# BLEU-1 Score on test data 190965502: 20.000
# BLEU-1 Score on test data 194197375: 45.000
# BLEU-1 Score on test data 1944813674: 42.857
# BLEU-1 Score on test data 2043372516: 40.000
# BLEU-1 Score on test data 205675005: 50.000
# BLEU-1 Score on test data 2064780645: 21.429
# BLEU-1 Score on test data 2066241589: 35.000
# BLEU-1 Score on test data 2067833088: 45.000
# BLEU-1 Score on test data 2068403258: 35.000
# BLEU-1 Score on test data 207015505: 52.632
# BLEU-1 Score on test data 2078709661: 28.571
# BLEU-1 Score on test data 2079499010: 30.000
# BLEU-1 Score on test data 2081446176: 33.333
# BLEU-1 Score on test data 2082620071: 50.000
# BLEU-1 Score on test data 2082663150: 35.714
# BLEU-1 Score on test data 2095478050: 45.000
# BLEU-1 Score on test data 2102902012: 36.193
# BLEU-1 Score on test data 210625425: 20.000
# BLEU-1 Score on test data 2109370875: 35.000
# BLEU-1 Score on test data 2112114341: 35.000
# BLEU-1 Score on test data 2112661738: 30.000
# BLEU-1 Score on test data 2113592981: 35.714
# BLEU-1 Score on test data 21167868: 35.714
# BLEU-1 Score on test data 212155635: 15.000
# BLEU-1 Score on test data 2123858003: 25.000
# BLEU-1 Score on test data 212536960: 45.000
# BLEU-1 Score on test data 212857743: 50.000
# BLEU-1 Score on test data 213269168: 35.000
# BLEU-1 Score on test data 213609234: 45.000
# BLEU-1 Score on test data 2148916767: 28.571
# BLEU-1 Score on test data 2159447283: 40.000
# BLEU-1 Score on test data 217583047: 31.579
# BLEU-1 Score on test data 2187904131: 10.000
# BLEU-1 Score on test data 2190899457: 28.656
# BLEU-1 Score on test data 2192026581: 21.429
# BLEU-1 Score on test data 2206282062: 28.656
# BLEU-1 Score on test data 2206600240: 31.579
# BLEU-1 Score on test data 2208310655: 40.000
# BLEU-1 Score on test data 2209496328: 25.000
# BLEU-1 Score on test data 2209751: 25.000
# BLEU-1 Score on test data 2210054257: 14.286
# BLEU-1 Score on test data 2212472643: 35.714
# BLEU-1 Score on test data 2214383094: 40.000
# BLEU-1 Score on test data 2219805467: 28.571
# BLEU-1 Score on test data 2219959872: 50.000
# BLEU-1 Score on test data 2223151597: 35.714
# BLEU-1 Score on test data 2224524855: 21.053
# BLEU-1 Score on test data 2230971412: 14.286
# BLEU-1 Score on test data 2250479700: 65.000
# BLEU-1 Score on test data 2251418114: 25.000
# BLEU-1 Score on test data 226115048: 47.561
# BLEU-1 Score on test data 227689211: 33.333
# BLEU-1 Score on test data 2279729059: 50.000
# BLEU-1 Score on test data 2280354512: 28.571
# BLEU-1 Score on test data 2281226546: 20.472
# BLEU-1 Score on test data 2289754578: 55.000
# BLEU-1 Score on test data 2295489839: 35.000
# BLEU-1 Score on test data 2297744130: 57.143
# BLEU-1 Score on test data 230105501: 58.814
# BLEU-1 Score on test data 2310452540: 25.000
# BLEU-1 Score on test data 2311881432: 42.805
# BLEU-1 Score on test data 2315320158: 40.000
# BLEU-1 Score on test data 2319963351: 50.000
# BLEU-1 Score on test data 2324842075: 50.000
# BLEU-1 Score on test data 2326795765: 21.320
# BLEU-1 Score on test data 233361142: 20.000
# BLEU-1 Score on test data 2334983049: 71.429
# BLEU-1 Score on test data 2340206885: 28.571
# BLEU-1 Score on test data 234580030: 21.429
# BLEU-1 Score on test data 2353119813: 42.857
# BLEU-1 Score on test data 2354516058: 36.787
# BLEU-1 Score on test data 2359784186: 47.619
# BLEU-1 Score on test data 2367317953: 28.571
# BLEU-1 Score on test data 2373370266: 42.857
# BLEU-1 Score on test data 2374523052: 35.714
# BLEU-1 Score on test data 2376252671: 28.571
# BLEU-1 Score on test data 2382847674: 47.368
# BLEU-1 Score on test data 2383712490: 47.619
# BLEU-1 Score on test data 2386635533: 63.158
# BLEU-1 Score on test data 2387197355: 35.000
# BLEU-1 Score on test data 2396025708: 20.000
# BLEU-1 Score on test data 2398915100: 28.571
# BLEU-1 Score on test data 2409312675: 21.429
# BLEU-1 Score on test data 241345721: 39.903
# BLEU-1 Score on test data 241345811: 35.000
# BLEU-1 Score on test data 241347580: 25.000
# BLEU-1 Score on test data 241347611: 35.714
# BLEU-1 Score on test data 241347803: 28.571
# BLEU-1 Score on test data 2417341107: 50.000
# BLEU-1 Score on test data 2417623030: 15.000
# BLEU-1 Score on test data 2420730259: 55.000
# BLEU-1 Score on test data 2430018178: 36.842
# BLEU-1 Score on test data 2434710077: 50.000
# BLEU-1 Score on test data 2439942035: 27.778
# BLEU-1 Score on test data 2445654384: 45.000
# BLEU-1 Score on test data 2463067409: 28.571
# BLEU-1 Score on test data 2473956981: 34.591
# BLEU-1 Score on test data 2474483208: 42.857
# BLEU-1 Score on test data 2474785004: 57.143
# BLEU-1 Score on test data 24759839: 35.000
# BLEU-1 Score on test data 2479180530: 33.333
# BLEU-1 Score on test data 2481490320: 40.000
# BLEU-1 Score on test data 2488783398: 42.805
# BLEU-1 Score on test data 2490365757: 28.571
# BLEU-1 Score on test data 2493782805: 40.000
# BLEU-1 Score on test data 2494088238: 57.143
# BLEU-1 Score on test data 2500785647: 35.000
# BLEU-1 Score on test data 2502975562: 55.556
# BLEU-1 Score on test data 2504683345: 14.286
# BLEU-1 Score on test data 2506113060: 45.000
# BLEU-1 Score on test data 2508837436: 33.333
# BLEU-1 Score on test data 2508850304: 15.000
# BLEU-1 Score on test data 2511787709: 49.124
# BLEU-1 Score on test data 2513060654: 36.842
# BLEU-1 Score on test data 2521794926: 39.903
# BLEU-1 Score on test data 2526989006: 21.429
# BLEU-1 Score on test data 2536946133: 15.000
# BLEU-1 Score on test data 2537601290: 33.333
# BLEU-1 Score on test data 2537665596: 61.111
# BLEU-1 Score on test data 2537801630: 15.000
# BLEU-1 Score on test data 2537817814: 23.781
# BLEU-1 Score on test data 2540751930: 28.571
# BLEU-1 Score on test data 2541104331: 21.053
# BLEU-1 Score on test data 2550027486: 35.000
# BLEU-1 Score on test data 2563482243: 50.000
# BLEU-1 Score on test data 2565847129: 18.520
# BLEU-1 Score on test data 2579268572: 21.053
# BLEU-1 Score on test data 2579699529: 45.000
# BLEU-1 Score on test data 2580215443: 25.000
# BLEU-1 Score on test data 2592398210: 40.000
# BLEU-1 Score on test data 2594042571: 53.204
# BLEU-1 Score on test data 2594459477: 30.000
# BLEU-1 Score on test data 2597088734: 30.000
# BLEU-1 Score on test data 2600229816: 50.000
# BLEU-1 Score on test data 2613209320: 20.000
# BLEU-1 Score on test data 2613993276: 42.857
# BLEU-1 Score on test data 2621771656: 14.286
# BLEU-1 Score on test data 262439544: 50.000
# BLEU-1 Score on test data 2632429064: 42.857
# BLEU-1 Score on test data 2636663855: 64.286
# BLEU-1 Score on test data 2638054798: 14.286
# BLEU-1 Score on test data 2641770481: 35.714
# BLEU-1 Score on test data 2644302353: 28.571
# BLEU-1 Score on test data 264461048: 35.714
# BLEU-1 Score on test data 2647394564: 10.000
# BLEU-1 Score on test data 2648165716: 25.000
# BLEU-1 Score on test data 264928854: 40.000
# BLEU-1 Score on test data 2654018684: 42.857
# BLEU-1 Score on test data 2669048370: 45.000
# BLEU-1 Score on test data 26758039: 40.000
# BLEU-1 Score on test data 2676015068: 40.000
# BLEU-1 Score on test data 268044066: 50.000
# BLEU-1 Score on test data 269361490: 25.000
# BLEU-1 Score on test data 2705925058: 20.000
# BLEU-1 Score on test data 2712352554: 40.000
# BLEU-1 Score on test data 2723024306: 39.903
# BLEU-1 Score on test data 2723477522: 21.429
# BLEU-1 Score on test data 272354004: 30.000
# BLEU-1 Score on test data 2734669176: 50.000
# BLEU-1 Score on test data 274313927: 42.857
# BLEU-1 Score on test data 2744330402: 30.000
# BLEU-1 Score on test data 2744600462: 42.857
# BLEU-1 Score on test data 275171617: 25.000
# BLEU-1 Score on test data 275854404: 40.000
# BLEU-1 Score on test data 2761119252: 35.714
# BLEU-1 Score on test data 2766630484: 20.000
# BLEU-1 Score on test data 2771424045: 55.000
# BLEU-1 Score on test data 2774025309: 35.714
# BLEU-1 Score on test data 2774267559: 28.571
# BLEU-1 Score on test data 2777021428: 42.857
# BLEU-1 Score on test data 2793597468: 42.857
# BLEU-1 Score on test data 2800531753: 42.857
# BLEU-1 Score on test data 2808838598: 55.000
# BLEU-1 Score on test data 2833509990: 35.714
# BLEU-1 Score on test data 2849169944: 28.571
# BLEU-1 Score on test data 2864577025: 44.444
# BLEU-1 Score on test data 2866974237: 35.000
# BLEU-1 Score on test data 2872778569: 28.571
# BLEU-1 Score on test data 2879966085: 43.344
# BLEU-1 Score on test data 2881561370: 35.000
# BLEU-1 Score on test data 288177922: 35.714
# BLEU-1 Score on test data 2884092603: 35.000
# BLEU-1 Score on test data 289560545: 27.778
# BLEU-1 Score on test data 2895700779: 30.000
# BLEU-1 Score on test data 289625522: 35.714
# BLEU-1 Score on test data 2896640216: 35.714
# BLEU-1 Score on test data 2908834379: 25.000
# BLEU-1 Score on test data 2917463531: 63.158
# BLEU-1 Score on test data 2922807898: 33.333
# BLEU-1 Score on test data 2923605305: 35.046
# BLEU-1 Score on test data 2934000107: 35.714
# BLEU-1 Score on test data 295258727: 20.000
# BLEU-1 Score on test data 2953704682: 28.571
# BLEU-1 Score on test data 2955083038: 18.576
# BLEU-1 Score on test data 2956562716: 33.252
# BLEU-1 Score on test data 2957679856: 45.000
# BLEU-1 Score on test data 2957702898: 25.000
# BLEU-1 Score on test data 2966901532: 40.000
# BLEU-1 Score on test data 2972245986: 50.000
# BLEU-1 Score on test data 2972901053: 50.000
# BLEU-1 Score on test data 2977103313: 25.000
# BLEU-1 Score on test data 2977128559: 30.000
# BLEU-1 Score on test data 2978394277: 42.857
# BLEU-1 Score on test data 2990977776: 57.143
# BLEU-1 Score on test data 2993822651: 45.405
# BLEU-1 Score on test data 2997191641: 45.000
# BLEU-1 Score on test data 3002051747: 14.286
# BLEU-1 Score on test data 3004291093: 45.000
# BLEU-1 Score on test data 300438143: 47.561
# BLEU-1 Score on test data 3004823335: 25.000
# BLEU-1 Score on test data 3009713124: 30.000
# BLEU-1 Score on test data 301582255: 25.000
# BLEU-1 Score on test data 3019857541: 21.429
# BLEU-1 Score on test data 3020218156: 49.766
# BLEU-1 Score on test data 3020578684: 15.789
# BLEU-1 Score on test data 3023753964: 33.333
# BLEU-1 Score on test data 3026459445: 35.000
# BLEU-1 Score on test data 3028561714: 22.222
# BLEU-1 Score on test data 303103036: 57.143
# BLEU-1 Score on test data 3036382555: 35.714
# BLEU-1 Score on test data 3037060954: 45.000
# BLEU-1 Score on test data 3037108254: 40.356
# BLEU-1 Score on test data 3041262779: 21.429
# BLEU-1 Score on test data 3046431231: 15.789
# BLEU-1 Score on test data 3047788420: 70.000
# BLEU-1 Score on test data 3048904615: 15.000
# BLEU-1 Score on test data 3051022611: 40.000
# BLEU-1 Score on test data 3052412278: 39.903
# BLEU-1 Score on test data 305673358: 14.286
# BLEU-1 Score on test data 3061422245: 28.571
# BLEU-1 Score on test data 3085973779: 35.000
# BLEU-1 Score on test data 3087225132: 28.896
# BLEU-1 Score on test data 3087336221: 19.048
# BLEU-1 Score on test data 3088572348: 36.842
# BLEU-1 Score on test data 3091921457: 25.000
# BLEU-1 Score on test data 3091962081: 35.714
# BLEU-1 Score on test data 3093325656: 35.714
# BLEU-1 Score on test data 3093744301: 21.429
# BLEU-1 Score on test data 3100442775: 30.000
# BLEU-1 Score on test data 3103231330: 50.000
# BLEU-1 Score on test data 3106857210: 50.000
# BLEU-1 Score on test data 3107558821: 30.000
# BLEU-1 Score on test data 3110018626: 14.286
# BLEU-1 Score on test data 3111897772: 14.286
# BLEU-1 Score on test data 311379220: 33.333
# BLEU-1 Score on test data 3121771055: 42.857
# BLEU-1 Score on test data 3122369444: 13.346
# BLEU-1 Score on test data 3125158798: 40.000
# BLEU-1 Score on test data 3127142756: 21.429
# BLEU-1 Score on test data 3139389284: 21.429
# BLEU-1 Score on test data 314454989: 47.368
# BLEU-1 Score on test data 3147399239: 60.000
# BLEU-1 Score on test data 3148098037: 38.889
# BLEU-1 Score on test data 3150742439: 45.000
# BLEU-1 Score on test data 3157039116: 55.728
# BLEU-1 Score on test data 3171035252: 36.842
# BLEU-1 Score on test data 317386541: 33.252
# BLEU-1 Score on test data 317488612: 10.000
# BLEU-1 Score on test data 3179952488: 21.429
# BLEU-1 Score on test data 3183777589: 57.143
# BLEU-1 Score on test data 3183883750: 20.000
# BLEU-1 Score on test data 3186265813: 42.857
# BLEU-1 Score on test data 3186472721: 57.895
# BLEU-1 Score on test data 3186685756: 30.000
# BLEU-1 Score on test data 3200120942: 40.000
# BLEU-1 Score on test data 3203286634: 20.000
# BLEU-1 Score on test data 3204579636: 50.000
# BLEU-1 Score on test data 3215238223: 35.000
# BLEU-1 Score on test data 3216316010: 60.000
# BLEU-1 Score on test data 3225025519: 35.714
# BLEU-1 Score on test data 3226541300: 10.000
# BLEU-1 Score on test data 3228517564: 39.903
# BLEU-1 Score on test data 3230602641: 39.903
# BLEU-1 Score on test data 3237799755: 35.714
# BLEU-1 Score on test data 3239891140: 38.940
# BLEU-1 Score on test data 3245266444: 57.143
# BLEU-1 Score on test data 3251234434: 33.252
# BLEU-1 Score on test data 3259222980: 37.898
# BLEU-1 Score on test data 3267720211: 55.000
# BLEU-1 Score on test data 3268191118: 28.571
# BLEU-1 Score on test data 3281225560: 31.669
# BLEU-1 Score on test data 3283021089: 35.714
# BLEU-1 Score on test data 3288839246: 50.000
# BLEU-1 Score on test data 3288928346: 35.000
# BLEU-1 Score on test data 3292277400: 16.667
# BLEU-1 Score on test data 3294336227: 35.000
# BLEU-1 Score on test data 3298378599: 45.000
# BLEU-1 Score on test data 3298547199: 28.571
# BLEU-1 Score on test data 3300643106: 35.000
# BLEU-1 Score on test data 3304763517: 53.204
# BLEU-1 Score on test data 3306464579: 40.000
# BLEU-1 Score on test data 3310851569: 35.714
# BLEU-1 Score on test data 3313691449: 20.000
# BLEU-1 Score on test data 3321248380: 42.043
# BLEU-1 Score on test data 3324375078: 11.111
# BLEU-1 Score on test data 3325578605: 11.765
# BLEU-1 Score on test data 3325960085: 21.429
# BLEU-1 Score on test data 3326024473: 28.571
# BLEU-1 Score on test data 3333039854: 25.000
# BLEU-1 Score on test data 3335127933: 35.714
# BLEU-1 Score on test data 3335873796: 45.000
# BLEU-1 Score on test data 3335885203: 42.857
# BLEU-1 Score on test data 3339319023: 35.714
# BLEU-1 Score on test data 3340639621: 45.000
# BLEU-1 Score on test data 3342445722: 17.295
# BLEU-1 Score on test data 3344175369: 50.000
# BLEU-1 Score on test data 3344578125: 42.857
# BLEU-1 Score on test data 3344798356: 50.000
# BLEU-1 Score on test data 334890559: 40.000
# BLEU-1 Score on test data 3351704877: 38.462
# BLEU-1 Score on test data 3353950389: 46.553
# BLEU-1 Score on test data 3354463693: 35.000
# BLEU-1 Score on test data 3361278843: 45.000
# BLEU-1 Score on test data 336460583: 35.714
# BLEU-1 Score on test data 3366571152: 21.429
# BLEU-1 Score on test data 3368819708: 20.000
# BLEU-1 Score on test data 3384702365: 30.000
# BLEU-1 Score on test data 3385430506: 45.000
# BLEU-1 Score on test data 3388094307: 25.000
# BLEU-1 Score on test data 3388618374: 25.000
# BLEU-1 Score on test data 3393274529: 30.000
# BLEU-1 Score on test data 3394654132: 35.000
# BLEU-1 Score on test data 3394992905: 38.889
# BLEU-1 Score on test data 3395176505: 42.105
# BLEU-1 Score on test data 339642119: 42.857
# BLEU-1 Score on test data 3396817186: 42.857
# BLEU-1 Score on test data 3405759441: 35.714
# BLEU-1 Score on test data 3410899419: 23.810
# BLEU-1 Score on test data 3415165462: 28.571
# BLEU-1 Score on test data 3416617727: 36.324
# BLEU-1 Score on test data 3425851292: 45.000
# BLEU-1 Score on test data 3427023324: 16.667
# BLEU-1 Score on test data 3433259846: 14.286
# BLEU-1 Score on test data 3435015880: 21.429
# BLEU-1 Score on test data 3435208408: 21.429
# BLEU-1 Score on test data 3435233065: 30.960
# BLEU-1 Score on test data 3435371117: 28.571
# BLEU-1 Score on test data 3445428367: 35.714
# BLEU-1 Score on test data 344865045: 46.121
# BLEU-1 Score on test data 3450158776: 28.571
# BLEU-1 Score on test data 3451623753: 45.242
# BLEU-1 Score on test data 3458577912: 22.222
# BLEU-1 Score on test data 3460992366: 45.000
# BLEU-1 Score on test data 3463034205: 30.000
# BLEU-1 Score on test data 3463342991: 30.000
# BLEU-1 Score on test data 3470703538: 68.421
# BLEU-1 Score on test data 347186933: 35.714
# BLEU-1 Score on test data 3473635435: 45.000
# BLEU-1 Score on test data 3474999131: 30.769
# BLEU-1 Score on test data 3477672764: 70.000
# BLEU-1 Score on test data 3481556478: 28.571
# BLEU-1 Score on test data 3482314155: 28.571
# BLEU-1 Score on test data 3486324591: 30.000
# BLEU-1 Score on test data 3488087117: 28.571
# BLEU-1 Score on test data 3498240367: 25.000
# BLEU-1 Score on test data 34988312: 15.000
# BLEU-1 Score on test data 3500342526: 35.714
# BLEU-1 Score on test data 3503021545: 20.000
# BLEU-1 Score on test data 3504275465: 18.097
# BLEU-1 Score on test data 3505701438: 42.857
# BLEU-1 Score on test data 3508389675: 50.000
# BLEU-1 Score on test data 3510218982: 27.778
# BLEU-1 Score on test data 3520079657: 15.000
# BLEU-1 Score on test data 3520199925: 30.000
# BLEU-1 Score on test data 3525041739: 9.995
# BLEU-1 Score on test data 3541483943: 50.000
# BLEU-1 Score on test data 3553374585: 35.714
# BLEU-1 Score on test data 3560771491: 64.286
# BLEU-1 Score on test data 356242936: 35.714
# BLEU-1 Score on test data 3562537872: 43.035
# BLEU-1 Score on test data 3569329986: 42.857
# BLEU-1 Score on test data 3569420080: 45.000
# BLEU-1 Score on test data 3571996084: 14.286
# BLEU-1 Score on test data 3572548523: 30.000
# BLEU-1 Score on test data 3575947093: 40.000
# BLEU-1 Score on test data 3578318751: 35.714
# BLEU-1 Score on test data 3578841731: 23.810
# BLEU-1 Score on test data 3578945620: 35.000
# BLEU-1 Score on test data 3579150322: 40.000
# BLEU-1 Score on test data 3580375310: 35.714
# BLEU-1 Score on test data 358114269: 50.000
# BLEU-1 Score on test data 3582920844: 28.571
# BLEU-1 Score on test data 3590653633: 26.602
# BLEU-1 Score on test data 3595956590: 52.632
# BLEU-1 Score on test data 3607489370: 36.842
# BLEU-1 Score on test data 3608585041: 24.768
# BLEU-1 Score on test data 3610460852: 35.000
# BLEU-1 Score on test data 3615175165: 38.732
# BLEU-1 Score on test data 3619232550: 20.000
# BLEU-1 Score on test data 3621717946: 39.903
# BLEU-1 Score on test data 3629489568: 45.000
# BLEU-1 Score on test data 3630332976: 38.889
# BLEU-1 Score on test data 3634828052: 35.000
# BLEU-1 Score on test data 3649382413: 45.000
# BLEU-1 Score on test data 3652150541: 30.000
# BLEU-1 Score on test data 3654674895: 50.000
# BLEU-1 Score on test data 365849741: 53.204
# BLEU-1 Score on test data 3663793993: 55.000
# BLEU-1 Score on test data 3664781437: 50.000
# BLEU-1 Score on test data 366567420: 50.000
# BLEU-1 Score on test data 3667157255: 30.000
# BLEU-1 Score on test data 3667822570: 18.576
# BLEU-1 Score on test data 3669564923: 25.000
# BLEU-1 Score on test data 3670131152: 40.000
# BLEU-1 Score on test data 3670205710: 42.857
# BLEU-1 Score on test data 3677318686: 64.286
# BLEU-1 Score on test data 3677702372: 33.333
# BLEU-1 Score on test data 3678885320: 69.231
# BLEU-1 Score on test data 3679405397: 45.030
# BLEU-1 Score on test data 3681967973: 35.714
# BLEU-1 Score on test data 369047365: 34.591
# BLEU-1 Score on test data 3691394196: 40.000
# BLEU-1 Score on test data 3693961165: 26.316
# BLEU-1 Score on test data 3697675767: 39.903
# BLEU-1 Score on test data 3702634572: 50.000
# BLEU-1 Score on test data 3711611500: 35.714
# BLEU-1 Score on test data 371269133: 42.857
# BLEU-1 Score on test data 3714551959: 21.429
# BLEU-1 Score on test data 3714944115: 45.000
# BLEU-1 Score on test data 3715471115: 28.571
# BLEU-1 Score on test data 3720366614: 21.429
# BLEU-1 Score on test data 3726076549: 45.000
# BLEU-1 Score on test data 3730011219: 45.242
# BLEU-1 Score on test data 3736180463: 38.095
# BLEU-1 Score on test data 3743157427: 42.857
# BLEU-1 Score on test data 3745030498: 45.000
# BLEU-1 Score on test data 3745354249: 60.000
# BLEU-1 Score on test data 375955411: 42.857
# BLEU-1 Score on test data 377406355: 49.713
# BLEU-1 Score on test data 3776965455: 42.857
# BLEU-1 Score on test data 37791887: 50.000
# BLEU-1 Score on test data 3783987753: 33.333
# BLEU-1 Score on test data 3788779998: 35.714
# BLEU-1 Score on test data 3789378919: 15.000
# BLEU-1 Score on test data 379505240: 28.571
# BLEU-1 Score on test data 3800969923: 38.095
# BLEU-1 Score on test data 381239475: 42.857
# BLEU-1 Score on test data 3815142931: 42.857
# BLEU-1 Score on test data 3815669424: 30.305
# BLEU-1 Score on test data 381748680: 45.000
# BLEU-1 Score on test data 3818131656: 79.893
# BLEU-1 Score on test data 3826408509: 21.429
# BLEU-1 Score on test data 3827301652: 57.074
# BLEU-1 Score on test data 3831874776: 15.789
# BLEU-1 Score on test data 3831987297: 28.571
# BLEU-1 Score on test data 3833511502: 25.000
# BLEU-1 Score on test data 383595746: 47.368
# BLEU-1 Score on test data 384080245: 45.000
# BLEU-1 Score on test data 384465575: 14.286
# BLEU-1 Score on test data 3847453204: 39.903
# BLEU-1 Score on test data 3849580150: 27.145
# BLEU-1 Score on test data 3859199015: 15.000
# BLEU-1 Score on test data 386470686: 35.714
# BLEU-1 Score on test data 3867308040: 45.000
# BLEU-1 Score on test data 3868284371: 33.252
# BLEU-1 Score on test data 3871177631: 50.000
# BLEU-1 Score on test data 3897459678: 45.405
# BLEU-1 Score on test data 3899250752: 25.000
# BLEU-1 Score on test data 39024981: 40.000
# BLEU-1 Score on test data 390921095: 35.000
# BLEU-1 Score on test data 391723162: 21.429
# BLEU-1 Score on test data 3925836925: 64.286
# BLEU-1 Score on test data 3927396708: 40.718
# BLEU-1 Score on test data 3929379436: 45.000
# BLEU-1 Score on test data 3944169186: 25.000
# BLEU-1 Score on test data 3948003394: 42.857
# BLEU-1 Score on test data 3970617963: 40.000
# BLEU-1 Score on test data 3970645807: 28.571
# BLEU-1 Score on test data 3972836203: 35.000
# BLEU-1 Score on test data 3977684660: 61.111
# BLEU-1 Score on test data 397815951: 20.000
# BLEU-1 Score on test data 3987140887: 28.571
# BLEU-1 Score on test data 398946421: 34.591
# BLEU-1 Score on test data 3996889070: 42.857
# BLEU-1 Score on test data 4017326833: 40.000
# BLEU-1 Score on test data 4033018747: 51.168
# BLEU-1 Score on test data 405253184: 15.000
# BLEU-1 Score on test data 4060351788: 31.532
# BLEU-1 Score on test data 4061778099: 18.576
# BLEU-1 Score on test data 4074473431: 40.000
# BLEU-1 Score on test data 4082808690: 34.428
# BLEU-1 Score on test data 4084139686: 50.000
# BLEU-1 Score on test data 4089583280: 45.000
# BLEU-1 Score on test data 4095232321: 40.000
# BLEU-1 Score on test data 4113033557: 31.669
# BLEU-1 Score on test data 4115261994: 33.252
# BLEU-1 Score on test data 413231421: 21.429
# BLEU-1 Score on test data 413737417: 21.429
# BLEU-1 Score on test data 4145119743: 25.000
# BLEU-1 Score on test data 4146483752: 40.000
# BLEU-1 Score on test data 4146533978: 25.000
# BLEU-1 Score on test data 4152802063: 10.000
# BLEU-1 Score on test data 416933689: 55.000
# BLEU-1 Score on test data 4170746161: 30.000
# BLEU-1 Score on test data 4175969090: 20.000
# BLEU-1 Score on test data 4185308266: 25.000
# BLEU-1 Score on test data 419638730: 30.000
# BLEU-1 Score on test data 4196898728: 28.571
# BLEU-1 Score on test data 4213476956: 39.903
# BLEU-1 Score on test data 4272747342: 31.579
# BLEU-1 Score on test data 4289135695: 25.000
# BLEU-1 Score on test data 4294773353: 44.444
# BLEU-1 Score on test data 4302249704: 35.714
# BLEU-1 Score on test data 4322208721: 55.000
# BLEU-1 Score on test data 4326926923: 47.368
# BLEU-1 Score on test data 432870699: 58.824
# BLEU-1 Score on test data 4329179652: 28.571
# BLEU-1 Score on test data 4329198220: 47.619
# BLEU-1 Score on test data 4344231645: 30.000
# BLEU-1 Score on test data 434642339: 26.316
# BLEU-1 Score on test data 4353551949: 49.713
# BLEU-1 Score on test data 4358650450: 47.561
# BLEU-1 Score on test data 4371749436: 25.000
# BLEU-1 Score on test data 4379493825: 28.571
# BLEU-1 Score on test data 4379588756: 10.000
# BLEU-1 Score on test data 4390537722: 45.000
# BLEU-1 Score on test data 439348091: 50.000
# BLEU-1 Score on test data 4397975773: 34.799
# BLEU-1 Score on test data 4406961500: 39.903
# BLEU-1 Score on test data 4407490214: 50.000
# BLEU-1 Score on test data 4408414886: 50.000
# BLEU-1 Score on test data 4411745355: 27.145
# BLEU-1 Score on test data 44129946: 40.000
# BLEU-1 Score on test data 4433551085: 30.000
# BLEU-1 Score on test data 44341119: 21.429
# BLEU-1 Score on test data 4441274429: 21.429
# BLEU-1 Score on test data 4442382200: 50.000
# BLEU-1 Score on test data 4442442651: 42.857
# BLEU-1 Score on test data 4442764150: 55.000
# BLEU-1 Score on test data 4443087970: 25.000
# BLEU-1 Score on test data 4443536449: 36.193
# BLEU-1 Score on test data 4448923515: 42.857
# BLEU-1 Score on test data 4450689424: 40.000
# BLEU-1 Score on test data 4470667650: 45.000
# BLEU-1 Score on test data 4477467862: 40.000
# BLEU-1 Score on test data 4477602852: 40.000
# BLEU-1 Score on test data 448252603: 45.000
# BLEU-1 Score on test data 4483432356: 35.000
# BLEU-1 Score on test data 4483752409: 30.000
# BLEU-1 Score on test data 4483989917: 42.857
# BLEU-1 Score on test data 4484638832: 42.857
# BLEU-1 Score on test data 4491246659: 15.789
# BLEU-1 Score on test data 4493390025: 58.333
# BLEU-1 Score on test data 44953142: 36.193
# BLEU-1 Score on test data 4496551407: 52.381
# BLEU-1 Score on test data 4502384999: 35.714
# BLEU-1 Score on test data 450746926: 21.429
# BLEU-1 Score on test data 4507760036: 25.000
# BLEU-1 Score on test data 4508496980: 55.000
# BLEU-1 Score on test data 4513166936: 30.000
# BLEU-1 Score on test data 451597318: 35.000
# BLEU-1 Score on test data 4523659515: 42.834
# BLEU-1 Score on test data 452419961: 9.091
# BLEU-1 Score on test data 4525768834: 49.536
# BLEU-1 Score on test data 4526155267: 38.889
# BLEU-1 Score on test data 4528304009: 40.000
# BLEU-1 Score on test data 4531004667: 42.857
# BLEU-1 Score on test data 4532756721: 19.951
# BLEU-1 Score on test data 4533797010: 37.152
# BLEU-1 Score on test data 4544194772: 61.830
# BLEU-1 Score on test data 4545767663: 31.783
# BLEU-1 Score on test data 4549048831: 15.000
# BLEU-1 Score on test data 4550700462: 35.000
# BLEU-1 Score on test data 4552756737: 34.591
# BLEU-1 Score on test data 4552874290: 50.000
# BLEU-1 Score on test data 4553604007: 35.714
# BLEU-1 Score on test data 4555412480: 40.718
# BLEU-1 Score on test data 4555514125: 35.714
# BLEU-1 Score on test data 4556002396: 35.000
# BLEU-1 Score on test data 455777014: 37.152
# BLEU-1 Score on test data 4565935527: 50.000
# BLEU-1 Score on test data 4573386995: 55.000
# BLEU-1 Score on test data 4576671: 38.889
# BLEU-1 Score on test data 4580064094: 40.000
# BLEU-1 Score on test data 4580064496: 55.556
# BLEU-1 Score on test data 4584925685: 21.429
# BLEU-1 Score on test data 4589502987: 46.553
# BLEU-1 Score on test data 4590049942: 45.000
# BLEU-1 Score on test data 4591183075: 50.000
# BLEU-1 Score on test data 4600629110: 25.000
# BLEU-1 Score on test data 4605605328: 35.000
# BLEU-1 Score on test data 4616068657: 70.000
# BLEU-1 Score on test data 4617869592: 20.000
# BLEU-1 Score on test data 4619879173: 40.000
# BLEU-1 Score on test data 4631136622: 28.896
# BLEU-1 Score on test data 4631830645: 19.048
# BLEU-1 Score on test data 4634063005: 15.789
# BLEU-1 Score on test data 4637336317: 40.000
# BLEU-1 Score on test data 4652665785: 35.000
# BLEU-1 Score on test data 4655361417: 50.000
# BLEU-1 Score on test data 465541156: 28.537
# BLEU-1 Score on test data 4656225038: 50.000
# BLEU-1 Score on test data 4659788392: 45.000
# BLEU-1 Score on test data 4665106597: 45.000
# BLEU-1 Score on test data 4667685590: 20.000
# BLEU-1 Score on test data 4669404758: 50.000
# BLEU-1 Score on test data 4669642298: 70.000
# BLEU-1 Score on test data 4671579541: 42.857
# BLEU-1 Score on test data 4672056076: 50.000
# BLEU-1 Score on test data 467514961: 40.000
# BLEU-1 Score on test data 4678130554: 55.000
# BLEU-1 Score on test data 4678723492: 22.243
# BLEU-1 Score on test data 4682822726: 40.000
# BLEU-1 Score on test data 4684583424: 33.252
# BLEU-1 Score on test data 4686363111: 28.571
# BLEU-1 Score on test data 468640364: 28.571
# BLEU-1 Score on test data 4686568156: 31.461
# BLEU-1 Score on test data 4688204116: 15.000
# BLEU-1 Score on test data 468918320: 45.000
# BLEU-1 Score on test data 4690280732: 30.000
# BLEU-1 Score on test data 4691117837: 33.333
# BLEU-1 Score on test data 4694510761: 35.714
# BLEU-1 Score on test data 4695719556: 19.025
# BLEU-1 Score on test data 4696331217: 45.242
# BLEU-1 Score on test data 4696903210: 33.333
# BLEU-1 Score on test data 4698463256: 45.000
# BLEU-1 Score on test data 4699461776: 35.000
# BLEU-1 Score on test data 4700435315: 35.714
# BLEU-1 Score on test data 4702734830: 40.000
# BLEU-1 Score on test data 4703514466: 35.000
# BLEU-1 Score on test data 4718120804: 25.000
# BLEU-1 Score on test data 4720666564: 30.000
# BLEU-1 Score on test data 4725325505: 42.857
# BLEU-1 Score on test data 4727348655: 35.714
# BLEU-1 Score on test data 4731709586: 28.571
# BLEU-1 Score on test data 473592754: 42.857
# BLEU-1 Score on test data 4738567166: 33.777
# BLEU-1 Score on test data 4738942164: 39.947
# BLEU-1 Score on test data 4738987510: 25.000
# BLEU-1 Score on test data 4738994499: 42.805
# BLEU-1 Score on test data 4741533543: 42.857
# BLEU-1 Score on test data 4741878277: 40.000
# BLEU-1 Score on test data 4742826670: 50.000
# BLEU-1 Score on test data 474652272: 30.000
# BLEU-1 Score on test data 4749166996: 50.000
# BLEU-1 Score on test data 4749855: 53.204
# BLEU-1 Score on test data 4751932433: 35.714
# BLEU-1 Score on test data 4760475302: 35.714
# BLEU-1 Score on test data 4762117658: 60.000
# BLEU-1 Score on test data 4775810124: 20.000
# BLEU-1 Score on test data 4775815811: 45.000
# BLEU-1 Score on test data 477607006: 38.095
# BLEU-1 Score on test data 4783176272: 39.903
# BLEU-1 Score on test data 4785056855: 28.826
# BLEU-1 Score on test data 4785666083: 45.000
# BLEU-1 Score on test data 4786187822: 37.898
# BLEU-1 Score on test data 4788507034: 42.857
# BLEU-1 Score on test data 4793039083: 33.333
# BLEU-1 Score on test data 4793562214: 54.545
# BLEU-1 Score on test data 4794844936: 10.000
# BLEU-1 Score on test data 4795708965: 40.000
# BLEU-1 Score on test data 479807115: 35.714
# BLEU-1 Score on test data 4799239390: 57.895
# BLEU-1 Score on test data 4799652268: 55.000
# BLEU-1 Score on test data 4800150389: 47.561
# BLEU-1 Score on test data 4802006392: 40.000
# BLEU-1 Score on test data 4803941821: 50.000
# BLEU-1 Score on test data 481054596: 50.000
# BLEU-1 Score on test data 4814019484: 45.000
# BLEU-1 Score on test data 4817804359: 40.000
# BLEU-1 Score on test data 4820694014: 42.857
# BLEU-1 Score on test data 4822527778: 22.621
# BLEU-1 Score on test data 4823906931: 36.842
# BLEU-1 Score on test data 4826608043: 7.143
# BLEU-1 Score on test data 4829533753: 50.000
# BLEU-1 Score on test data 4831684754: 64.286
# BLEU-1 Score on test data 4842066356: 15.000
# BLEU-1 Score on test data 4845541718: 24.903
# BLEU-1 Score on test data 4848627833: 15.000
# BLEU-1 Score on test data 4852389235: 35.714
# BLEU-1 Score on test data 485296499: 38.889
# BLEU-1 Score on test data 4857542541: 65.000
# BLEU-1 Score on test data 4858608182: 22.222
# BLEU-1 Score on test data 4859795801: 30.000
# BLEU-1 Score on test data 4860806028: 45.000
# BLEU-1 Score on test data 4864177176: 64.286
# BLEU-1 Score on test data 4871416563: 42.857
# BLEU-1 Score on test data 4872410849: 64.286
# BLEU-1 Score on test data 4872766179: 40.000
# BLEU-1 Score on test data 4876342546: 50.000
# BLEU-1 Score on test data 4879725156: 55.000
# BLEU-1 Score on test data 488064659: 50.000
# BLEU-1 Score on test data 4882763253: 50.000
# BLEU-1 Score on test data 4886280540: 52.318
# BLEU-1 Score on test data 4889084974: 9.048
# BLEU-1 Score on test data 4889307357: 45.242
# BLEU-1 Score on test data 4893568355: 30.000
# BLEU-1 Score on test data 4897113571: 25.000
# BLEU-1 Score on test data 4897359709: 40.000
# BLEU-1 Score on test data 4903277818: 42.857
# BLEU-1 Score on test data 490527535: 57.143
# BLEU-1 Score on test data 4908009544: 21.429
# BLEU-1 Score on test data 4913610444: 44.444
# BLEU-1 Score on test data 4913813677: 51.642
# BLEU-1 Score on test data 4915228657: 16.667
# BLEU-1 Score on test data 4917931600: 60.000
# BLEU-1 Score on test data 4918469719: 34.428
# BLEU-1 Score on test data 4921249499: 43.035
# BLEU-1 Score on test data 4925702921: 40.000
# BLEU-1 Score on test data 4929777339: 30.000
# BLEU-1 Score on test data 4931289200: 37.152
# BLEU-1 Score on test data 4933973457: 40.000
# BLEU-1 Score on test data 4934470318: 40.937
# BLEU-1 Score on test data 493654365: 30.000
# BLEU-1 Score on test data 4938920379: 35.000
# BLEU-1 Score on test data 493937377: 59.169
# BLEU-1 Score on test data 4940604843: 75.000
# BLEU-1 Score on test data 4942732639: 43.344
# BLEU-1 Score on test data 4946431326: 45.000
# BLEU-1 Score on test data 4950818767: 55.000
# BLEU-1 Score on test data 4951335575: 30.000
# BLEU-1 Score on test data 4956455528: 42.857
# BLEU-1 Score on test data 4957325128: 45.000
# BLEU-1 Score on test data 4959315763: 45.242
# BLEU-1 Score on test data 4960801678: 39.903
# BLEU-1 Score on test data 496418696: 36.842
# BLEU-1 Score on test data 4964921391: 38.732
# BLEU-1 Score on test data 4968285215: 22.621
# BLEU-1 Score on test data 4968291657: 57.143
# BLEU-1 Score on test data 496971341: 25.000
# BLEU-1 Score on test data 4970590451: 21.429
# BLEU-1 Score on test data 4972988789: 55.000
# BLEU-1 Score on test data 4979962304: 27.778
# BLEU-1 Score on test data 4980845265: 64.627
# BLEU-1 Score on test data 4981438692: 60.000
# BLEU-1 Score on test data 4983762807: 20.000
# BLEU-1 Score on test data 498444334: 21.429
# BLEU-1 Score on test data 4985424423: 45.000
# BLEU-1 Score on test data 4985704: 40.000
# BLEU-1 Score on test data 4987509732: 65.000
# BLEU-1 Score on test data 501680472: 31.579
# BLEU-1 Score on test data 505004077: 24.768
# BLEU-1 Score on test data 5056620714: 25.000
# BLEU-1 Score on test data 505837388: 28.571
# BLEU-1 Score on test data 508838116: 50.000
# BLEU-1 Score on test data 5123250615: 46.154
# BLEU-1 Score on test data 512616265: 21.320
# BLEU-1 Score on test data 5138003138: 13.621
# BLEU-1 Score on test data 5142873217: 42.857
# BLEU-1 Score on test data 5176080732: 31.669
# BLEU-1 Score on test data 521529438: 22.222
# BLEU-1 Score on test data 5216466221: 42.805
# BLEU-1 Score on test data 52226520: 21.429
# BLEU-1 Score on test data 5225304863: 60.000
# BLEU-1 Score on test data 5231178541: 47.561
# BLEU-1 Score on test data 524073179: 65.000
# BLEU-1 Score on test data 524296878: 21.429
# BLEU-1 Score on test data 526619673: 42.857
# BLEU-1 Score on test data 5273781492: 40.000
# BLEU-1 Score on test data 528500099: 42.857
# BLEU-1 Score on test data 528517845: 63.158
# BLEU-1 Score on test data 5287405: 40.000
# BLEU-1 Score on test data 5303395266: 50.000
# BLEU-1 Score on test data 5326961690: 25.000
# BLEU-1 Score on test data 533602654: 16.667
# BLEU-1 Score on test data 5359437945: 45.000
# BLEU-1 Score on test data 5387261695: 28.571
# BLEU-1 Score on test data 539705321: 42.942
# BLEU-1 Score on test data 5403974988: 45.000
# BLEU-1 Score on test data 542648687: 20.000
# BLEU-1 Score on test data 5433157092: 38.095
# BLEU-1 Score on test data 5444535493: 33.293
# BLEU-1 Score on test data 5455501634: 27.145
# BLEU-1 Score on test data 5468460528: 39.903
# BLEU-1 Score on test data 5501340599: 57.143
# BLEU-1 Score on test data 5507574163: 30.000
# BLEU-1 Score on test data 5523538212: 30.960
# BLEU-1 Score on test data 5534272962: 35.000
# BLEU-1 Score on test data 5543900069: 25.000
# BLEU-1 Score on test data 5605133486: 30.000
# BLEU-1 Score on test data 561906323: 21.429
# BLEU-1 Score on test data 5635975939: 36.842
# BLEU-1 Score on test data 566384456: 35.000
# BLEU-1 Score on test data 570996053: 50.000
# BLEU-1 Score on test data 5721362205: 40.000
# BLEU-1 Score on test data 5723818088: 52.632
# BLEU-1 Score on test data 5727359138: 69.003
# BLEU-1 Score on test data 5731856709: 50.000
# BLEU-1 Score on test data 5743380092: 65.000
# BLEU-1 Score on test data 5791568: 42.105
# BLEU-1 Score on test data 5840232264: 57.143
# BLEU-1 Score on test data 59027529: 28.571
# BLEU-1 Score on test data 5903521315: 50.000
# BLEU-1 Score on test data 5920741851: 23.810
# BLEU-1 Score on test data 5932908042: 36.842
# BLEU-1 Score on test data 5958376440: 28.571
# BLEU-1 Score on test data 5968404576: 47.368
# BLEU-1 Score on test data 599235529: 14.286
# BLEU-1 Score on test data 6043197241: 40.000
# BLEU-1 Score on test data 6046473448: 44.444
# BLEU-1 Score on test data 6078212486: 28.216
# BLEU-1 Score on test data 6080521675: 35.714
# BLEU-1 Score on test data 6091899771: 40.000
# BLEU-1 Score on test data 6100315: 45.000
# BLEU-1 Score on test data 6105998656: 42.857
# BLEU-1 Score on test data 6157897194: 52.632
# BLEU-1 Score on test data 61745811: 42.857
# BLEU-1 Score on test data 6178994097: 30.000
# BLEU-1 Score on test data 6186146093: 35.000
# BLEU-1 Score on test data 618797331: 30.000
# BLEU-1 Score on test data 6190349317: 50.000
# BLEU-1 Score on test data 619169586: 50.000
# BLEU-1 Score on test data 6192034820: 28.571
# BLEU-1 Score on test data 6199134021: 30.000
# BLEU-1 Score on test data 6210888137: 38.732
# BLEU-1 Score on test data 6221289833: 54.290
# BLEU-1 Score on test data 6227789666: 45.000
# BLEU-1 Score on test data 6234467033: 40.000
# BLEU-1 Score on test data 62597667: 21.429
# BLEU-1 Score on test data 6269296633: 40.000
# BLEU-1 Score on test data 6273590324: 11.530
# BLEU-1 Score on test data 6274309052: 38.732
# BLEU-1 Score on test data 6276644870: 21.429
# BLEU-1 Score on test data 627714170: 45.000
# BLEU-1 Score on test data 6321643151: 46.553
# BLEU-1 Score on test data 6342262756: 25.000
# BLEU-1 Score on test data 6371136393: 26.289
# BLEU-1 Score on test data 63787714: 20.000
# BLEU-1 Score on test data 6386779555: 33.777
# BLEU-1 Score on test data 6408975653: 50.000
# BLEU-1 Score on test data 6437497301: 35.000
# BLEU-1 Score on test data 6454057197: 30.000
# BLEU-1 Score on test data 6457288631: 30.000
# BLEU-1 Score on test data 6491222037: 40.000
# BLEU-1 Score on test data 6502476865: 21.429
# BLEU-1 Score on test data 6524893225: 35.714
# BLEU-1 Score on test data 6532234215: 28.537
# BLEU-1 Score on test data 6533934303: 10.000
# BLEU-1 Score on test data 6563237641: 40.000
# BLEU-1 Score on test data 6575547265: 19.025
# BLEU-1 Score on test data 6618942119: 40.000
# BLEU-1 Score on test data 664341930: 35.000
# BLEU-1 Score on test data 664470170: 25.000
# BLEU-1 Score on test data 6662693149: 45.000
# BLEU-1 Score on test data 6668564001: 26.316
# BLEU-1 Score on test data 6685838035: 53.204
# BLEU-1 Score on test data 674513893: 14.286
# BLEU-1 Score on test data 675153: 25.000
# BLEU-1 Score on test data 6788339456: 35.714
# BLEU-1 Score on test data 6800484706: 35.714
# BLEU-1 Score on test data 6827875949: 42.857
# BLEU-1 Score on test data 6838340009: 36.193
# BLEU-1 Score on test data 6839530214: 57.074
# BLEU-1 Score on test data 6842319991: 55.000
# BLEU-1 Score on test data 6878446432: 30.000
# BLEU-1 Score on test data 6892085645: 50.000
# BLEU-1 Score on test data 6925158300: 40.000
# BLEU-1 Score on test data 6939396159: 40.000
# BLEU-1 Score on test data 6962504000: 35.714
# BLEU-1 Score on test data 6966952728: 39.947
# BLEU-1 Score on test data 6968761623: 35.714
# BLEU-1 Score on test data 6981039831: 42.857
# BLEU-1 Score on test data 7018032339: 30.960
# BLEU-1 Score on test data 7061176565: 34.591
# BLEU-1 Score on test data 7062790747: 45.000
# BLEU-1 Score on test data 7130577881: 55.000
# BLEU-1 Score on test data 71406758: 28.571
# BLEU-1 Score on test data 7149253081: 14.286
# BLEU-1 Score on test data 71521921: 35.714
# BLEU-1 Score on test data 7175934082: 30.000
# BLEU-1 Score on test data 72218201: 28.571
# BLEU-1 Score on test data 7277119012: 39.903
# BLEU-1 Score on test data 7278335118: 35.000
# BLEU-1 Score on test data 7278854458: 64.286
# BLEU-1 Score on test data 7284553600: 57.143
# BLEU-1 Score on test data 7339914832: 60.000
# BLEU-1 Score on test data 7396934178: 15.000
# BLEU-1 Score on test data 7402359070: 45.000
# BLEU-1 Score on test data 7430281548: 50.000
# BLEU-1 Score on test data 7455508610: 14.286
# BLEU-1 Score on test data 7466310132: 50.000
# BLEU-1 Score on test data 7470011060: 30.000
# BLEU-1 Score on test data 7517274630: 25.000
# BLEU-1 Score on test data 75180828: 40.000
# BLEU-1 Score on test data 7526370420: 49.945
# BLEU-1 Score on test data 7529986808: 28.571
# BLEU-1 Score on test data 7544290736: 28.571
# BLEU-1 Score on test data 755045922: 45.000
# BLEU-1 Score on test data 756909515: 17.647
# BLEU-1 Score on test data 757046028: 45.000
# BLEU-1 Score on test data 7635804008: 20.000
# BLEU-1 Score on test data 7643799764: 40.718
# BLEU-1 Score on test data 7669392800: 22.702
# BLEU-1 Score on test data 7673295758: 42.857
# BLEU-1 Score on test data 7700377542: 33.333
# BLEU-1 Score on test data 7701250756: 57.143
# BLEU-1 Score on test data 7714755346: 50.000
# BLEU-1 Score on test data 7718605530: 42.805
# BLEU-1 Score on test data 7719524174: 40.000
# BLEU-1 Score on test data 7772746168: 29.828
# BLEU-1 Score on test data 7778073672: 35.714
# BLEU-1 Score on test data 7779718252: 40.000
# BLEU-1 Score on test data 78171801: 50.000
# BLEU-1 Score on test data 7865722022: 15.576
# BLEU-1 Score on test data 79433987: 40.000
# BLEU-1 Score on test data 79770548: 42.857
# BLEU-1 Score on test data 7983388093: 38.095
# BLEU-1 Score on test data 7988459911: 60.000
# BLEU-1 Score on test data 8036608675: 28.571
# BLEU-1 Score on test data 8047664455: 35.714
# BLEU-1 Score on test data 8071166084: 42.857
# BLEU-1 Score on test data 8116539330: 28.571
# BLEU-1 Score on test data 8133150444: 40.000
# BLEU-1 Score on test data 8159685316: 23.810
# BLEU-1 Score on test data 8170813639: 21.429
# BLEU-1 Score on test data 8209386413: 35.714
# BLEU-1 Score on test data 821605360: 40.000
# BLEU-1 Score on test data 8251170369: 33.293
# BLEU-1 Score on test data 82676249: 45.000
# BLEU-1 Score on test data 841397013: 33.293
# BLEU-1 Score on test data 8443156: 64.286
# BLEU-1 Score on test data 860271719: 21.429
# BLEU-1 Score on test data 86120374: 38.732
# BLEU-1 Score on test data 86131989: 20.000
# BLEU-1 Score on test data 91875542: 34.428
# BLEU-1 Score on test data 981727078: 18.097
# BLEU-1 Score on test data 991459823: 45.000
# Total time taken: 414.2103054523468 sec

# %%
np.mean(scores)
# Out:
# 36.8370527014049

# %%
print(len(good))
print(len(bad))
# Out:
# 106
# 297
